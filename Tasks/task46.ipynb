# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('russia_losses_equipment.csv')

# %%
data
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  BUK  \
# 0   2022-02-26    3        27          26   146   706               49    1
# 1   2022-02-28    5        29          29   150   816               74    1
# 2   2022-03-01    6        29          29   198   846               77    1
# 3   2022-03-02    7        30          31   211   862               85    1
# 4   2022-03-03    8        30          31   217   900               90    1
# 5   2022-03-04    9        33          37   251   939              105    1
# 6   2022-03-05   10        39          40   269   945              105    1
# 7   2022-03-06   11        44          48   285   985              109    1
# 8   2022-03-07   12        46          68   290   999              117    1
# 9   2022-03-08   13        48          80   303  1036              120    1
# 10  2022-03-09   14        49          81   317  1070              120    1
# ...

# %%
data.isnull().sum()
# Out:
# date                      0
# day                       0
# aircraft                  0
# helicopter                0
# tank                      0
# APC                       0
# field artillery           0
# BUK                       0
# MRL                       0
# military auto             0
# fuel tank                 0
# drone                     0
# naval ship                0
# anti-aircraft warfare     0
# special equipment        17
# dtype: int64

# %%
data.shape
# Out:
# (19, 15)

# %%
data.columns=data.columns.str.replace(' ','')

# %%
data.columns
# Out:
# Index(['date', 'day', 'aircraft', 'helicopter', 'tank', 'APC',
#        'fieldartillery', 'BUK', 'MRL', 'militaryauto', 'fueltank', 'drone',
#        'navalship', 'anti-aircraftwarfare', 'specialequipment'],
#       dtype='object')

# %%
del data['specialequipment']

# %%
data.columns
# Out:
# Index(['date', 'day', 'aircraft', 'helicopter', 'tank', 'APC',
#        'fieldartillery', 'BUK', 'MRL', 'militaryauto', 'fueltank', 'drone',
#        'navalship', 'anti-aircraftwarfare'],
#       dtype='object')

# %%
data.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  fieldartillery  BUK  MRL  \
# 0  2022-02-26    3        27          26   146  706              49    1    4
# 1  2022-02-28    5        29          29   150  816              74    1   21
# 2  2022-03-01    6        29          29   198  846              77    1   24
# 3  2022-03-02    7        30          31   211  862              85    1   40
# 4  2022-03-03    8        30          31   217  900              90    1   42
#
#    militaryauto  fueltank  drone  navalship  anti-aircraftwarfare
# 0            30        60      2          2                     0
# 1           291        60      3          2                     5
# 2           305        60      3          2                     7
# 3           355        60      3          2                     9
# 4           374        60      3          2                    11

# %%
data
# Out:
#           date  day  aircraft  helicopter  tank   APC  fieldartillery  BUK  \
# 0   2022-02-26    3        27          26   146   706              49    1
# 1   2022-02-28    5        29          29   150   816              74    1
# 2   2022-03-01    6        29          29   198   846              77    1
# 3   2022-03-02    7        30          31   211   862              85    1
# 4   2022-03-03    8        30          31   217   900              90    1
# 5   2022-03-04    9        33          37   251   939             105    1
# 6   2022-03-05   10        39          40   269   945             105    1
# 7   2022-03-06   11        44          48   285   985             109    1
# 8   2022-03-07   12        46          68   290   999             117    1
# 9   2022-03-08   13        48          80   303  1036             120    1
# 10  2022-03-09   14        49          81   317  1070             120    1
# ...

# %%
data1=pd.get_dummies(data['navalship'])

# %%
data1
# Out:
#     2  3
# 0   1  0
# 1   1  0
# 2   1  0
# 3   1  0
# 4   1  0
# 5   1  0
# 6   1  0
# 7   1  0
# 8   0  1
# 9   0  1
# 10  0  1
# 11  0  1
# 12  0  1
# 13  0  1
# 14  0  1
# 15  0  1
# 16  0  1
# 17  0  1
# 18  0  1

# %%
f=[data,data1]
df=pd.concat(f,axis=1)

# %%
df
# Out:
#           date  day  aircraft  helicopter  tank   APC  fieldartillery  BUK  \
# 0   2022-02-26    3        27          26   146   706              49    1
# 1   2022-02-28    5        29          29   150   816              74    1
# 2   2022-03-01    6        29          29   198   846              77    1
# 3   2022-03-02    7        30          31   211   862              85    1
# 4   2022-03-03    8        30          31   217   900              90    1
# 5   2022-03-04    9        33          37   251   939             105    1
# 6   2022-03-05   10        39          40   269   945             105    1
# 7   2022-03-06   11        44          48   285   985             109    1
# 8   2022-03-07   12        46          68   290   999             117    1
# 9   2022-03-08   13        48          80   303  1036             120    1
# 10  2022-03-09   14        49          81   317  1070             120    1
# ...

# %%
df.columns
# Out:
# Index([                'date',                  'day',             'aircraft',
#                  'helicopter',                 'tank',                  'APC',
#              'fieldartillery',                  'BUK',                  'MRL',
#                'militaryauto',             'fueltank',                'drone',
#                   'navalship', 'anti-aircraftwarfare',                      2,
#                             3],
#       dtype='object')

# %%
plt.bar(df['day'],df['helicopter'],color='r')
plt.xticks(df['day'])
plt.title('Calculatiom')
plt.
plt.show()
